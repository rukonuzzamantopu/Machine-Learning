# %%
phone_number = "01330885039"
print(phone_number)
# Out:
# 01330885039

# %%
num = 1330885039
print(num)
# Out:
# 1330885039

# %%
age = 20
height = 1.75
name = "Topu"
is_passed = True

print(type(age), type(height), type(name), type(is_passed) )
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>

# %% [markdown]
# ## Taking Input in Python

# %%
name = input("Enter your name: ")

print(name)

# %%
age  = input("Enter your age: ")

print (age ,type(age))
# Out:
# 35 <class 'str'>

# %%
age  = input("Enter your age: ")

age = int(age)
print (age ,type(age))
# Out:
# 25 <class 'int'>

# %%
height = input("Enter your height: ")

print(height, type(height))
# Out:
# 36.8 <class 'str'>

# %%
height = float(input("Enter your height: "))

print(height, type(height))
# Out:
# 34.897 <class 'float'>

# %%
height = input("Enter your height: ")

print(height, type(height))
height = height + 0.78
print(height, type(height))
# Out:
# 67.987 <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 height = input("Enter your height: ")
#       2
#       3 print(height, type(height))
# ----> 4 height = height + 0.78
#       5 print(height, type(height))
#
# TypeError: can only concatenate str (not "float") to str
